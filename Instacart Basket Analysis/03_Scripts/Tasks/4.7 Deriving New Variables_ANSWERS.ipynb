# %% [markdown]
# ## EXERCISE

# %% [markdown]
# #01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #02. Importing Data set

# %%
path_name = r'/Users/geetika/Documents/Python/Instacart Basket Analysis/02_Data'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path_name, 'Prepared Data', 'orders_products_merged.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32434212, 18)

# %%
# Create a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %% [markdown]
# #03. User defined functions

# %%
# Define a function

def price_label(row):
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High range'
    else:
        return 'Not enough data'

# %%
# Apply the function

df['price_range'] = df.apply(price_label, axis = 1)
# Out:
# /var/folders/7w/cp4_h97s3bd3qx9ww9ss1g_r0000gn/T/ipykernel_5614/4221219494.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis = 1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# #04. If-Statements with the loc() Function

# %%
# loc() Statements on the subset
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/7w/cp4_h97s3bd3qx9ww9ss1g_r0000gn/T/ipykernel_5614/3358994131.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
# loc() Statements on the entire dataframe 
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# NaN                   21890146
# Low-range product     10126384
# High-range product      417682
# Name: price_range_loc, dtype: int64

# %% [markdown]
# #05. For-Loops

# %%
for x in range(30, 45):
    print("My age is %d" % (x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in ords_prods_merge['orders_day_of_week']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: busiest_day, dtype: int64

# %% [markdown]
# ## TASK

# %%
result_days = []

for value in ords_prods_merge['orders_day_of_week']:
    if value == 0 or value == 1:
        result_days.append('Busiest days')
    elif value == 3 or value == 4:
        result_days.append('Slowest days')
    else:
        result_days.append('Regular days')

# %%
result_days
# Out:
# ['Regular days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regular days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regular days',
#  'Regular days',
#  'Busiest days',
#  'Busiest days',
#  'Regular days',
#  'Regular days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regular days',
#  'Regular days',
#  'Busiest days',
#  'Regular days',
#  'Regular days',
#  'Busiest days',
#  'Regular days',
#  'Regular days',
#  'Regular days',
#  'Slowest days',
#  'Regular days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regular days',
#  'Slowest days',
#  'Slowest days',
#  'Regular days',
#  'Regular days',
#  'Busiest days',
#  'Busiest days',
#  'Regular days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regular days',
# ...

# %%
ords_prods_merge['busiest_day_2'] = result_days

# %%
ords_prods_merge['busiest_day_2'].value_counts(dropna = False)
# Out:
# Regular days    12927461
# Busiest days    11875462
# Slowest days     7631289
# Name: busiest_day_2, dtype: int64

# %%
busiest_days = 6209632 + 5665830
regular_days = 4500246 + 4217766 + 4209449
slowest_days = 3844096 + 3787193

# %%
regular_days, busiest_days, slowest_days
# Out:
# (12927461, 11875462, 7631289)

# %%
ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: order_hour_of_day, dtype: int64

# %%
result_hours = []

for hour in ords_prods_merge['order_hour_of_day']:
    if hour == 10 or hour == 11 or hour == 14 or hour == 15 or hour == 13 or hour == 12 or hour == 16 or hour == 9:
        result_hours.append('Busiest hours')
    elif hour == 17 or hour == 8 or hour == 18 or hour == 19 or hour == 20 or hour == 7 or hour == 21 or hour == 22:
        result_hours.append('Regular hours')
    else:
        result_hours.append('Slowest hours')

# %%
result_hours
# Out:
# ['Regular days',
#  'Regular days',
#  'Busiest hours',
#  'Regular days',
#  'Busiest hours',
#  'Regular days',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Regular days',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Regular days',
#  'Busiest hours',
#  'Regular days',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Regular days',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Regular days',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
#  'Busiest hours',
# ...

# %%
ords_prods_merge['busiest_hour'] = result_hours

# %%
ords_prods_merge['busiest_hour'].value_counts(dropna = False)
# Out:
# Busiest hours    21137262
# Regular days     10006752
# Slowest days      1290198
# Name: busiest_hour, dtype: int64

# %%
21137262 + 10006752 + 1290198
# Out:
# 32434212

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge price_range_loc  \
# ...

# %%
ords_prods_merge.to_pickle(os.path.join(path_name, 'Prepared Data', 'ords_prods_merge.pkl'))
