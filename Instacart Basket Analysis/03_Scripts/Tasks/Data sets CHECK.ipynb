# %%
import pandas as pd
import numpy as np
import os

# %%
path_name = r'/Users/geetika/Documents/Python/Instacart Basket Analysis/02_Data'

# %%
#df_1 = pd.read_pickle(os.path.join(path_name, 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
#df_1.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge price_range_loc  \
# ...

# %%
#df_2 = pd.read_pickle(os.path.join(path_name, 'Prepared Data', 'orders_products_combined.pkl'))

# %%
#df_2.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
#df_3 = pd.read_pickle(os.path.join(path_name, 'Prepared Data', 'orders_products_merged.pkl'))

# %%
#df_3.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %%
df_4 = pd.read_pickle(os.path.join(path_name, 'Prepared Data', 'ords_prods_merge_E4.8.pkl'))

# %%
df_4.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge  max_order  \
# ...

# %%
df_5 = pd.read_pickle(os.path.join(path_name, 'Prepared Data', 'ords_prods_custs_merge.pkl'))

# %%
df_5 = df_5.drop(columns = '_merge')

# %%
df_5.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...   busiest_hour  First Name  surname  gender    state age  \
# ...

# %%
df_4.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', '_merge', 'max_order', 'loyalty_flag',
#        'mean_price_of_products', 'spending_flag',
#        'median_days_since_prior_order', 'Regularity_of_customer'],
#       dtype='object')

# %%
df_5.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'price_range_loc', 'busiest_day',
#        'busiest_day_2', 'busiest_hour', 'First Name', 'surname', 'gender',
#        'state', 'age', 'date_joined', 'number_of_dependents', 'marital_status',
#        'income'],
#       dtype='object')

# %%
drop_columns = ['order_number', 'orders_day_of_week',
       'order_hour_of_day', 'days_since_prior_order', 'product_id',
       'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
       'department_id', 'prices', '_merge']
df_4 = df_4.drop(columns = drop_columns)

# %%
df_4.head()
# Out:
#    order_id  user_id  max_order  loyalty_flag  mean_price_of_products  \
# 0   2539329        1         10  New customer                6.367797
# 1   2398795        1         10  New customer                6.367797
# 2    473747        1         10  New customer                6.367797
# 3   2254736        1         10  New customer                6.367797
# 4    431534        1         10  New customer                6.367797
#
#   spending_flag  median_days_since_prior_order Regularity_of_customer
# 0   Low spender                           20.5  Non-frequent customer
# 1   Low spender                           20.5  Non-frequent customer
# 2   Low spender                           20.5  Non-frequent customer
# 3   Low spender                           20.5  Non-frequent customer
# 4   Low spender                           20.5  Non-frequent customer

# %%
df_4.shape
# Out:
# (32434212, 8)

# %%
df_5.shape
# Out:
# (32434212, 26)

# %%
df_4 = df_4.drop(columns = 'user_id')

# %%
df_6 = df_5.merge(df_4, on = ['order_id'], indicator = True)
