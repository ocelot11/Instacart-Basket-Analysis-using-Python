# %%
import pandas as pd
import numpy as np
import os

# %%
path_name = r'/Users/geetika/Documents/Python/Instacart Basket Analysis/02_Data'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path_name, 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
df.describe()
# Out:
#            order_id         user_id    order_number  orders_day_of_week  \
# count  1.000000e+06  1000000.000000  1000000.000000      1000000.000000
# mean   1.710240e+06   101788.547547       18.731714            2.686741
# std    9.873682e+05    59011.894306       18.563841            2.053382
# min    5.000000e+00        1.000000        1.000000            0.000000
# 25%    8.555392e+05    50641.000000        5.000000            1.000000
# 50%    1.709734e+06   101164.000000       12.000000            2.000000
# 75%    2.565079e+06   152132.000000       27.000000            5.000000
# max    3.421068e+06   206209.000000       99.000000            6.000000
#
#        order_hour_of_day  days_since_prior_order      product_id  \
# count     1000000.000000           939915.000000  1000000.000000
# mean           13.272235               10.646367    27119.966748
# std             4.218017                8.467237    15578.819637
# min             0.000000                0.000000      196.000000
# 25%            10.000000                5.000000    13176.000000
# 50%            13.000000                7.000000    26088.000000
# 75%            16.000000               14.000000    47766.000000
# max            23.000000               30.000000    49235.000000
#
#        add_to_cart_order       reordered        aisle_id   department_id  \
# count     1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean            6.078493        0.769933       44.407396        8.740095
# std             5.695749        0.420876       28.925073        6.419989
# min             1.000000        0.000000       21.000000        4.000000
# 25%             2.000000        1.000000       24.000000        4.000000
# 50%             4.000000        1.000000       24.000000        4.000000
# 75%             8.000000        1.000000       67.000000       16.000000
# max            99.000000        1.000000      121.000000       20.000000
#
#                prices
# count  1000000.000000
# mean         7.819497
# std          3.641458
# min          1.000000
# 25%          6.300000
# 50%          9.000000
# 75%         10.300000
# max         14.800000

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# 1         Soda        77              7     9.0   both
# 2         Soda        77              7     9.0   both
# 3         Soda        77              7     9.0   both
# 4         Soda        77              7     9.0   both
# 5         Soda        77              7     9.0   both
# 6         Soda        77              7     9.0   both
# 7         Soda        77              7     9.0   both
# 8         Soda        77              7     9.0   both
# 9         Soda        77              7     9.0   both

# %%
df['department_id'].value_counts()
# Out:
# 4     611084
# 16    169624
# 20    108866
# 7      44710
# 19     38095
# 13     22656
# 14      3751
# 17      1214
# Name: department_id, dtype: int64

# %%
df.groupby('product_name')

# %% [markdown]
# #02. agg() Function

# %%
df.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# #03. Multiple Aggregations

# %%
df.groupby('department_id').agg({'order_number':['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
df.groupby('department_id').agg({'order_number':['mean', 'min', 'max'], 'prices':['mean', 'min', 'max']})
# Out:
#               order_number            prices
#                       mean min max      mean  min   max
# department_id
# 4                18.825780   1  99  8.850788  2.7  14.0
# 7                17.472355   1  99  9.845439  9.0  13.4
# 13               17.993423   1  99  3.596284  3.2  10.9
# 14               19.246334   1  99  4.000000  4.0   4.0
# 16               19.463012   1  99  3.725790  1.3  12.6
# 17               11.294069   1  98  1.000000  1.0   1.0
# 19               19.305237   1  99  4.589048  2.7   6.8
# 20               17.599636   1  99  9.794003  2.3  14.8

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
# 15   2293453       19             2                   5                 14
# 16   1973799       19             5                   6                 12
# 17    532817       19             7                   4                 17
# 18   1573906       21            10                   3                 10
# 19   1593000       31            10                   3                  8
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
# 15                     6.0         196                  3          0
# 16                     8.0         196                 15          1
# 17                     6.0         196                  1          1
# 18                     6.0         196                  2          0
# 19                     7.0         196                 17          0
#
#    product_name  aisle_id  department_id  prices _merge  max_order
# 0          Soda        77              7     9.0   both         10
# 1          Soda        77              7     9.0   both         10
# 2          Soda        77              7     9.0   both         10
# 3          Soda        77              7     9.0   both         10
# 4          Soda        77              7     9.0   both         10
# 5          Soda        77              7     9.0   both         10
# 6          Soda        77              7     9.0   both         10
# 7          Soda        77              7     9.0   both         10
# 8          Soda        77              7     9.0   both         10
# 9          Soda        77              7     9.0   both         10
# 10         Soda        77              7     9.0   both         22
# 11         Soda        77              7     9.0   both         22
# 12         Soda        77              7     9.0   both         22
# 13         Soda        77              7     9.0   both         22
# 14         Soda        77              7     9.0   both         22
# 15         Soda        77              7     9.0   both          9
# 16         Soda        77              7     9.0   both          9
# 17         Soda        77              7     9.0   both          9
# 18         Soda        77              7     9.0   both         33
# 19         Soda        77              7     9.0   both         20

# %%
ords_prods_merge[ords_prods_merge['user_id'] == 19]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 15         2293453       19             2                   5
# 16         1973799       19             5                   6
# 17          532817       19             7                   4
# 2269387    2474845       19             6                   5
# 3028920      86918       19             9                   5
# ...            ...      ...           ...                 ...
# 10410323     86918       19             9                   5
# 10410397     86918       19             9                   5
# 10410923     86918       19             9                   5
# 10411246     86918       19             9                   5
# 10424771     86918       19             9                   5
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 15                       14                     6.0         196
# 16                       12                     8.0         196
# 17                       17                     6.0         196
# 2269387                  13                    20.0       17224
# 3028920                  16                     8.0        9387
# ...                     ...                     ...         ...
# 10410323                 16                     8.0       22608
# 10410397                 16                     8.0       16855
# 10410923                 16                     8.0       22999
# 10411246                 16                     8.0       35042
# 10424771                 16                     8.0       31087
#
#           add_to_cart_order  reordered                        product_name  \
# 15                        3          0                                Soda
# 16                       15          1                                Soda
# 17                        1          1                                Soda
# 2269387                   5          0    Oats & Honey Gluten Free Granola
# 3028920                  16          0                 Granny Smith Apples
# ...                     ...        ...                                 ...
# 10410323                 15          0     Fat Free Italian Salad Dressing
# 10410397                 18          0        Banana Dippers Banana Slices
# 10410923                 19          0  30% Less Sodium Taco Seasoning Mix
# 10411246                 20          0                         Black Beans
# 10424771                 21          0     Whole Kernel Corn No Salt Added
#
#           aisle_id  department_id  prices _merge  max_order
# 15              77              7     9.0   both          9
# 16              77              7     9.0   both          9
# 17              77              7     9.0   both          9
# 2269387          3             19     1.6   both          9
# 3028920         24              4     8.8   both          9
# ...            ...            ...     ...    ...        ...
# 10410323        89             13     4.8   both          9
# 10410397       116              1     9.5   both          9
# 10410923       104             13     2.7   both          9
# 10411246        59             15     9.1   both          9
# 10424771        81             15     7.5   both          9
#
# [204 rows x 15 columns]

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge[ords_prods_merge['user_id'] == 19]

# %%
ords_prods_merge.head(100)

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: loyalty_flag, dtype: int64

# %%
15891077 + 10293737 + 6249398
# Out:
# 32434212

# %%
15876776 + 10284093 + 6243990
# Out:
# 32404859

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3
